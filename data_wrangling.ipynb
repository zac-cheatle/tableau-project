# %% [markdown]
# # Citi Bike Analytics Data Clean/Merge

# %%
# import dependencies
import pandas as pd

# %%
# import csv files
df1 = pd.read_csv("bike data files/oct_19.csv")  
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
df2 = pd.read_csv("bike data files/nov_19.csv")

# %%
df3 = pd.read_csv("bike data files/dec_19.csv")

# %%
df4 = pd.read_csv("bike data files/jan_20.csv")

# %%
df5 = pd.read_csv("bike data files/feb_20.csv")

# %%
df6 = pd.read_csv("bike data files/march_20.csv")

# %%
df7= pd.read_csv("bike data files/april_20.csv")

# %%
df8 = pd.read_csv("bike data files/may_20.csv")

# %%
df9 = pd.read_csv("bike data files/june_20.csv")

# %%
df10 = pd.read_csv("bike data files/july_20.csv")

# %%
df11 = pd.read_csv("bike data files/aug_20.csv")

# %%
df12 = pd.read_csv("bike data files/sept_20.csv")

# %%
# merge datasets
citibike = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
citibike
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1               212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2               569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3              1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4              1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike.to_csv('citibike.csv', sep = ',')
